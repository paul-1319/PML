# %%
#open a text file in 'Write mode to write the given lines
f=open("/content/textfile",'w')
f.write("first line\n")
f.write("second line\n")
f.write("third line\n")
f.close()
#Open a text file in'Read' mode to read and print the available lines-readline function
k=open("/content/textfile",'r')
print(k.readline())
print(k.readline())
print(k.readline())
k.close()
# Out:
# first line
#
# second line
#
# third line

# %%
#OPen a text file in 'Append' mode to add/append new line inputs
m=open("/content/textfile",'a')
m.write("Fourth line\n")
m.write("Fifth line\n")
m.close()

#open a text file in read mode to read and print the available full text-read function
p=open("/content/textfile",'r')
print(p.read())
p.close()
# Out:
# first line
# second line
# third line
# Fourth line
# Fifth line

# %%
with open("/content/textfile",'r')as file:
  lines=file.readlines()
  print(lines)

['first line\n', 'second line\n', 'third line\n', 'Fourth line\n', 'Fifth line\n']

import json
#JSON string
x='{"name":"John","age":30,"city":"New York"}'
#Convert JSON string to python dictionary
y=json.loads(x)
print(y["age"])
# Out:
# ['first line\n', 'second line\n', 'third line\n', 'Fourth line\n', 'Fifth line\n']
# 30

# %%
#Python dictionary
data={
    "name":"John",
    "age":30,
    "city":"New York"
}
#Convert python dictionary to JSON string
Json_data=json.dumps(data)
print(Json_data)
# Out:
# {"name": "John", "age": 30, "city": "New York"}
